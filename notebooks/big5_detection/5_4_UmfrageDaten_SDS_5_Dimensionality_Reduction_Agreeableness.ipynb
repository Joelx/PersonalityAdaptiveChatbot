# %%
from utility import *
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# the feature space becomes sparse as we increased the dimensionality of small datasets. This makes the classifeir easily overfit and the solution is simply to reduce the dimensionality.

# %%
from featurization import *
import pandas as pd 
import numpy as np


train = pd.read_csv('Joel\\datasets\\sds\\train_04.csv')
test = pd.read_csv('Joel\\datasets\\sds\\test_04.csv')
train_features, test_features, feature_names = featurize(train, test, 'tfidf_glove')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Max\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Emoji re....
# Num dots....
# Punctuation....
# Sentiment Scores....
# Text Features....
# Glove.....
#   0%|          | 0/56 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# DONE!

# %% [markdown]
# ## Feature Selection
# ### SelectKBest

# %%
test[test.ver_bin == 0].shape[0]
# Out:
# 11

# %% [markdown]
# #### Agreeableness

# %%
y_train = np.where(train.ver_bin.values == 1, 1, 0)
y_test = np.where(test.ver_bin.values == 1, 1, 0)

# %%
from sklearn.feature_selection import SelectKBest

selector = SelectKBest(k = 80)
train_features_selected = selector.fit_transform(train_features, y_train)
test_features_selected = selector.transform(test_features)
run_log_reg(train_features_selected, test_features_selected, y_train, y_test)
# Out:
# F1: 0.670 | Pr: 0.546 | Re: 1.000 | AUC: 0.466 | Accuracy: 0.508
# SGDClassifier(loss='log', n_jobs=-1)

# %%
# Lets run a for loop to select the value of K that optimizes F1

f1_scores = []

for k in tqdm_notebook(range(1, train_features.shape[1])):
    selector = SelectKBest(k = k)
    train_features_selected = selector.fit_transform(train_features, y_train)
    test_features_selected = selector.transform(test_features)
    f1_scores.append(run_log_reg(train_features_selected, test_features_selected, y_train, y_test, alpha = 1e-2, return_f1 = True, verbose = 0))
f1_scores = np.array(f1_scores)
# Out:
#   0%|          | 0/308 [00:00<?, ?it/s]

# %%
# Now let's plot the F1 scores:
import matplotlib.pyplot as plt

# %matplotlib inline

x = list(range(1, train_features.shape[1]))
plt.plot(x, f1_scores)
plt.xlabel('Number of Features')
plt.ylabel('F1 Scores')
plt.title('F1 Scores vs Num Features')
plt.grid()
plt.show()

# %%
print(np.argmax(f1_scores) + 1)
# Out:
# 7

# %%
selector = SelectKBest(k = 7)
train_features_selected = selector.fit_transform(train_features, y_train)
test_features_selected = selector.transform(test_features)
run_log_reg(train_features_selected, test_features_selected, y_train, y_test, alpha = 1e-2)
# Out:
# F1: 0.750 | Pr: 0.650 | Re: 1.000 | AUC: 0.561 | Accuracy: 0.667
# SGDClassifier(alpha=0.01, loss='log', n_jobs=-1)

# %%
# we can use get_support() to find out exactly which features were selected
np.array(feature_names)[selector.get_support()]
# Out:
# array(['fasttext_27', 'fasttext_34', 'fasttext_138', 'fasttext_180',
#        'fasttext_184', 'fasttext_185', 'fasttext_249'], dtype='<U19')

# %% [markdown]
# A disadvantage of SelectKBest is that we manually need to select the number of features we want to keep. SelectPercentile does the same thing, except this time we can pass the percentage of features we want to keep.

# %% [markdown]
# ### SelectPercentgile

# %%
from sklearn.feature_selection import SelectPercentile

f1_scores = []

for percentage in tqdm_notebook(range(1, 101)):
    selector = SelectPercentile(percentile = percentage)
    train_features_selected = selector.fit_transform(train_features, y_train)
    test_features_selected = selector.transform(test_features)
    f1_scores.append(run_log_reg(train_features_selected, test_features_selected, y_train, y_test, alpha = 1e-2, return_f1 = True, verbose = 0))
f1_scores = np.array(f1_scores)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# Now let's plot the F1 scores:
import matplotlib.pyplot as plt

# %matplotlib inline

x = list(range(1, 101))
plt.plot(x, f1_scores)
plt.xlabel('Percentage of Features')
plt.ylabel('F1 Scores')
plt.title('F1 Scores vs Num Features')
plt.grid()
plt.show()

# %%
print(np.argmax(f1_scores) + 1)
# Out:
# 2

# %%
selector = SelectPercentile(percentile = 2)
train_features_selected = selector.fit_transform(train_features, y_train)
test_features_selected = selector.transform(test_features)
run_log_reg(train_features_selected, test_features_selected, y_train, y_test, alpha = 1e-2)
# Out:
# F1: 0.750 | Pr: 0.650 | Re: 1.000 | AUC: 0.562 | Accuracy: 0.667
# SGDClassifier(alpha=0.01, loss='log', n_jobs=-1)

# %%
np.array(feature_names)[selector.get_support()]
# Out:
# array(['fasttext_27', 'fasttext_34', 'fasttext_138', 'fasttext_180',
#        'fasttext_184', 'fasttext_185', 'fasttext_249'], dtype='<U19')

# %% [markdown]
# ### RFECV (Recursive Featgures Elimination
#
#
# RFE is a backward feature selection technique that uses an estimator to calculate the feature importance at each stage. The word recursive in the name implies that the technique recursively removes features that are not important for classifiction.
#
# We'll use the CV variant which uses cross-validation inside each loop to determine how many features to remove in each loop. RFECV needs an estimator which has the feature_importances_ attribute so we'll use SGDClassifier with log loss.

# %%
# Since we have a hold out Test set that we would like to use - Let's create a `PredefinedSplit`
from sklearn.model_selection import PredefinedSplit

X = sparse.vstack((train_features, test_features))
test_fold = [-1 for _ in range(train_features.shape[0])] + [0 for _ in range(test_features.shape[0])]     # We need to label -1 for the train set and 0 for test set
y = np.concatenate([y_train, y_test])
ps = PredefinedSplit(test_fold)

# %%
from sklearn.feature_selection import RFECV

log_reg = SGDClassifier(loss = 'log', alpha = 1e-3)

selector = RFECV(log_reg, scoring = 'f1', n_jobs = -1, cv = ps, verbose = 1)
selector.fit(X, y)
# Out:
# Fitting estimator with 309 features.
# Fitting estimator with 308 features.
# Fitting estimator with 307 features.
# Fitting estimator with 306 features.
# Fitting estimator with 305 features.
# Fitting estimator with 304 features.
# Fitting estimator with 303 features.
# Fitting estimator with 302 features.
# Fitting estimator with 301 features.
# Fitting estimator with 300 features.
# Fitting estimator with 299 features.
# Fitting estimator with 298 features.
# Fitting estimator with 297 features.
# Fitting estimator with 296 features.
# Fitting estimator with 295 features.
# Fitting estimator with 294 features.
# Fitting estimator with 293 features.
# Fitting estimator with 292 features.
# Fitting estimator with 291 features.
# Fitting estimator with 290 features.
# Fitting estimator with 289 features.
# Fitting estimator with 288 features.
# Fitting estimator with 287 features.
# Fitting estimator with 286 features.
# Fitting estimator with 285 features.
# Fitting estimator with 284 features.
# Fitting estimator with 283 features.
# Fitting estimator with 282 features.
# Fitting estimator with 281 features.
# Fitting estimator with 280 features.
# Fitting estimator with 279 features.
# Fitting estimator with 278 features.
# Fitting estimator with 277 features.
# Fitting estimator with 276 features.
# Fitting estimator with 275 features.
# Fitting estimator with 274 features.
# Fitting estimator with 273 features.
# Fitting estimator with 272 features.
# Fitting estimator with 271 features.
# Fitting estimator with 270 features.
# Fitting estimator with 269 features.
# Fitting estimator with 268 features.
# Fitting estimator with 267 features.
# Fitting estimator with 266 features.
# Fitting estimator with 265 features.
# Fitting estimator with 264 features.
# Fitting estimator with 263 features.
# Fitting estimator with 262 features.
# Fitting estimator with 261 features.
# Fitting estimator with 260 features.
# Fitting estimator with 259 features.
# Fitting estimator with 258 features.
# Fitting estimator with 257 features.
# Fitting estimator with 256 features.
# Fitting estimator with 255 features.
# Fitting estimator with 254 features.
# Fitting estimator with 253 features.
# Fitting estimator with 252 features.
# Fitting estimator with 251 features.
# Fitting estimator with 250 features.
# Fitting estimator with 249 features.
# Fitting estimator with 248 features.
# Fitting estimator with 247 features.
# Fitting estimator with 246 features.
# Fitting estimator with 245 features.
# Fitting estimator with 244 features.
# Fitting estimator with 243 features.
# Fitting estimator with 242 features.
# Fitting estimator with 241 features.
# Fitting estimator with 240 features.
# Fitting estimator with 239 features.
# Fitting estimator with 238 features.
# Fitting estimator with 237 features.
# Fitting estimator with 236 features.
# Fitting estimator with 235 features.
# Fitting estimator with 234 features.
# Fitting estimator with 233 features.
# Fitting estimator with 232 features.
# Fitting estimator with 231 features.
# Fitting estimator with 230 features.
# Fitting estimator with 229 features.
# Fitting estimator with 228 features.
# Fitting estimator with 227 features.
# Fitting estimator with 226 features.
# Fitting estimator with 225 features.
# Fitting estimator with 224 features.
# Fitting estimator with 223 features.
# Fitting estimator with 222 features.
# Fitting estimator with 221 features.
# Fitting estimator with 220 features.
# Fitting estimator with 219 features.
# Fitting estimator with 218 features.
# Fitting estimator with 217 features.
# Fitting estimator with 216 features.
# Fitting estimator with 215 features.
# Fitting estimator with 214 features.
# Fitting estimator with 213 features.
# Fitting estimator with 212 features.
# Fitting estimator with 211 features.
# Fitting estimator with 210 features.
# Fitting estimator with 209 features.
# Fitting estimator with 208 features.
# Fitting estimator with 207 features.
# Fitting estimator with 206 features.
# Fitting estimator with 205 features.
# Fitting estimator with 204 features.
# Fitting estimator with 203 features.
# Fitting estimator with 202 features.
# Fitting estimator with 201 features.
# Fitting estimator with 200 features.
# Fitting estimator with 199 features.
# Fitting estimator with 198 features.
# Fitting estimator with 197 features.
# Fitting estimator with 196 features.
# Fitting estimator with 195 features.
# Fitting estimator with 194 features.
# Fitting estimator with 193 features.
# Fitting estimator with 192 features.
# Fitting estimator with 191 features.
# Fitting estimator with 190 features.
# Fitting estimator with 189 features.
# Fitting estimator with 188 features.
# Fitting estimator with 187 features.
# Fitting estimator with 186 features.
# Fitting estimator with 185 features.
# Fitting estimator with 184 features.
# Fitting estimator with 183 features.
# Fitting estimator with 182 features.
# Fitting estimator with 181 features.
# Fitting estimator with 180 features.
# Fitting estimator with 179 features.
# Fitting estimator with 178 features.
# Fitting estimator with 177 features.
# Fitting estimator with 176 features.
# Fitting estimator with 175 features.
# Fitting estimator with 174 features.
# Fitting estimator with 173 features.
# Fitting estimator with 172 features.
# Fitting estimator with 171 features.
# Fitting estimator with 170 features.
# Fitting estimator with 169 features.
# Fitting estimator with 168 features.
# Fitting estimator with 167 features.
# Fitting estimator with 166 features.
# Fitting estimator with 165 features.
# Fitting estimator with 164 features.
# Fitting estimator with 163 features.
# Fitting estimator with 162 features.
# Fitting estimator with 161 features.
# Fitting estimator with 160 features.
# Fitting estimator with 159 features.
# Fitting estimator with 158 features.
# Fitting estimator with 157 features.
# Fitting estimator with 156 features.
# Fitting estimator with 155 features.
# Fitting estimator with 154 features.
# Fitting estimator with 153 features.
# Fitting estimator with 152 features.
# Fitting estimator with 151 features.
# Fitting estimator with 150 features.
# Fitting estimator with 149 features.
# Fitting estimator with 148 features.
# Fitting estimator with 147 features.
# Fitting estimator with 146 features.
# Fitting estimator with 145 features.
# Fitting estimator with 144 features.
# Fitting estimator with 143 features.
# Fitting estimator with 142 features.
# Fitting estimator with 141 features.
# Fitting estimator with 140 features.
# Fitting estimator with 139 features.
# Fitting estimator with 138 features.
# Fitting estimator with 137 features.
# Fitting estimator with 136 features.
# Fitting estimator with 135 features.
# Fitting estimator with 134 features.
# Fitting estimator with 133 features.
# Fitting estimator with 132 features.
# Fitting estimator with 131 features.
# Fitting estimator with 130 features.
# Fitting estimator with 129 features.
# Fitting estimator with 128 features.
# Fitting estimator with 127 features.
# Fitting estimator with 126 features.
# Fitting estimator with 125 features.
# Fitting estimator with 124 features.
# Fitting estimator with 123 features.
# Fitting estimator with 122 features.
# Fitting estimator with 121 features.
# Fitting estimator with 120 features.
# Fitting estimator with 119 features.
# Fitting estimator with 118 features.
# Fitting estimator with 117 features.
# Fitting estimator with 116 features.
# Fitting estimator with 115 features.
# Fitting estimator with 114 features.
# Fitting estimator with 113 features.
# Fitting estimator with 112 features.
# Fitting estimator with 111 features.
# Fitting estimator with 110 features.
# Fitting estimator with 109 features.
# Fitting estimator with 108 features.
# Fitting estimator with 107 features.
# Fitting estimator with 106 features.
# Fitting estimator with 105 features.
# Fitting estimator with 104 features.
# Fitting estimator with 103 features.
# Fitting estimator with 102 features.
# Fitting estimator with 101 features.
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# RFECV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#       estimator=SGDClassifier(alpha=0.001, loss='log'), n_jobs=-1, scoring='f1',
#       verbose=1)

# %%
# Now lets select the best features and check the performance
train_features_selected = selector.transform(train_features)
test_features_selected = selector.transform(test_features)

run_log_reg(train_features_selected, test_features_selected, y_train, y_test, alpha = 1e-1)
# Out:
# F1: 0.811 | Pr: 0.982 | Re: 0.769 | AUC: 0.833 | Accuracy: 0.825
# SGDClassifier(alpha=0.1, loss='log', n_jobs=-1)

# %%
# Lets check which features were selected 

print('Number of features selected : {}'.format(selector.n_features_))
np.array(feature_names)[selector.support_]
# Out:
# Number of features selected : 46
# array(['num_dots', 'length_in_chars', 'fasttext_6', 'fasttext_10',
#        'fasttext_19', 'fasttext_26', 'fasttext_27', 'fasttext_34',
#        'fasttext_37', 'fasttext_39', 'fasttext_55', 'fasttext_60',
#        'fasttext_65', 'fasttext_77', 'fasttext_93', 'fasttext_118',
#        'fasttext_120', 'fasttext_121', 'fasttext_138', 'fasttext_143',
#        'fasttext_148', 'fasttext_161', 'fasttext_180', 'fasttext_181',
#        'fasttext_184', 'fasttext_185', 'fasttext_193', 'fasttext_209',
#        'fasttext_210', 'fasttext_215', 'fasttext_220', 'fasttext_222',
#        'fasttext_240', 'fasttext_242', 'fasttext_244', 'fasttext_249',
#        'fasttext_260', 'fasttext_263', 'fasttext_264', 'fasttext_268',
#        'fasttext_276', 'fasttext_277', 'fasttext_280', 'fasttext_282',
#        'fasttext_288', 'fasttext_298'], dtype='<U19')

# %% [markdown]
# ### SFS (Sequential Forward Selection)
# Finally, let's try SFS - which does the same thing as RFE instead adds features sequentially. SFS starts with 0 features and adds features 1-by-1 in each loop in a greedy manner. One small difference is that SFS solely uses the feature sets performance on the CV set as a metric for selecting the best features, unlike RFE which used model weights (feature_importances_)

# %%
# Note: MLxtend provides the SFS Implementation
from mlxtend.feature_selection import SequentialFeatureSelector

log_reg = SGDClassifier(loss = 'log', alpha = 1e-2)

selector = SequentialFeatureSelector(log_reg, k_features = 'best', floating = True, cv = ps, scoring = 'f1', verbose = 1, n_jobs = -1) # k_features = 'best' returns the best subset of features
selector.fit(X.tocsr(), y)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 286 out of 309 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 309 out of 309 | elapsed:    1.0s finished
# Features: 1/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 308 out of 308 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Features: 2/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 307 out of 307 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.0s finished
# Features: 3/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 306 out of 306 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.0s finished
# Features: 4/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 305 out of 305 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s finished
# Features: 5/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 304 out of 304 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# Features: 6/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 303 out of 303 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   6 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    0.0s finished
# Features: 7/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 302 out of 302 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    0.0s finished
# Features: 8/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 301 out of 301 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.0s finished
# Features: 9/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   9 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    0.0s finished
# Features: 10/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 299 out of 299 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.0s finished
# Features: 11/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 298 out of 298 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    0.0s finished
# Features: 12/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 297 out of 297 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  12 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    0.0s finished
# Features: 13/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 296 out of 296 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  13 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:    0.0s finished
# Features: 14/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 295 out of 295 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  14 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:    0.0s finished
# Features: 15/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 294 out of 294 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    0.0s finished
# Features: 16/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 293 out of 293 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  16 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:    0.0s finished
# Features: 17/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 292 out of 292 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  17 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:    0.0s finished
# Features: 18/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 268 out of 291 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 291 out of 291 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  18 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:    0.0s finished
# Features: 19/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 290 out of 290 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  19 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:    0.0s finished
# Features: 20/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 289 out of 289 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# Features: 21/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 288 out of 288 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:    0.0s finished
# Features: 22/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 264 out of 287 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 287 out of 287 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    0.0s finished
# Features: 23/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 286 out of 286 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:    0.0s finished
# Features: 24/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 262 out of 285 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 285 out of 285 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    0.0s finished
# Features: 25/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 284 out of 284 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    0.0s finished
# Features: 26/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 283 out of 283 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    0.0s finished
# Features: 27/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 282 out of 282 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    0.0s finished
# Features: 28/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 281 out of 281 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    0.0s finished
# Features: 29/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 280 out of 280 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    0.0s finished
# Features: 30/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 279 out of 279 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    0.0s finished
# Features: 31/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 278 out of 278 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    0.0s finished
# Features: 32/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 254 out of 277 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 277 out of 277 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    0.0s finished
# Features: 33/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 253 out of 276 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 276 out of 276 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    0.0s finished
# Features: 34/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 275 out of 275 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    0.0s finished
# Features: 35/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 274 out of 274 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    0.0s finished
# Features: 36/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 273 out of 273 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:    0.0s finished
# Features: 37/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 272 out of 272 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 out of  37 | elapsed:    0.0s finished
# Features: 38/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 271 out of 271 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  38 out of  38 | elapsed:    0.0s finished
# Features: 39/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 270 out of 270 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  39 out of  39 | elapsed:    0.0s finished
# Features: 40/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 269 out of 269 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:    0.0s finished
# Features: 41/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 268 out of 268 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  41 out of  41 | elapsed:    0.0s finished
# Features: 42/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 267 out of 267 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 out of  42 | elapsed:    0.0s finished
# Features: 43/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 266 out of 266 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  43 out of  43 | elapsed:    0.0s finished
# Features: 44/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 265 out of 265 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  44 out of  44 | elapsed:    0.0s finished
# Features: 45/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 264 out of 264 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:    0.0s finished
# Features: 46/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 263 out of 263 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 out of  46 | elapsed:    0.0s finished
# Features: 47/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 262 out of 262 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  47 out of  47 | elapsed:    0.0s finished
# Features: 48/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 261 out of 261 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    0.0s finished
# Features: 49/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 260 out of 260 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  49 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  49 out of  49 | elapsed:    0.0s finished
# Features: 50/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 259 out of 259 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.0s finished
# Features: 51/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 258 out of 258 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  51 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  51 out of  51 | elapsed:    0.0s finished
# Features: 52/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 257 out of 257 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:    0.0s finished
# Features: 53/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 256 out of 256 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  53 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:    0.0s finished
# Features: 53/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 256 out of 256 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  53 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:    0.0s finished
# Features: 54/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 255 out of 255 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:    0.0s finished
# Features: 55/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 254 out of 254 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  55 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:    0.0s finished
# Features: 55/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 254 out of 254 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  55 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:    0.0s finished
# Features: 56/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 253 out of 253 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  56 out of  56 | elapsed:    0.0s finished
# Features: 57/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 252 out of 252 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  57 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  57 out of  57 | elapsed:    0.0s finished
# Features: 58/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 251 out of 251 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  58 out of  58 | elapsed:    0.0s finished
# Features: 59/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  36 out of  59 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  59 out of  59 | elapsed:    0.0s finished
# Features: 60/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 249 out of 249 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.0s finished
# Features: 61/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 248 out of 248 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  38 out of  61 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  61 out of  61 | elapsed:    0.0s finished
# Features: 62/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 247 out of 247 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  62 out of  62 | elapsed:    0.0s finished
# Features: 63/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 246 out of 246 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  40 out of  63 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  63 out of  63 | elapsed:    0.0s finished
# Features: 64/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 245 out of 245 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Features: 65/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 244 out of 244 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  42 out of  65 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  65 out of  65 | elapsed:    0.0s finished
# Features: 66/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 243 out of 243 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  66 out of  66 | elapsed:    0.0s finished
# Features: 67/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 242 out of 242 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  44 out of  67 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  67 out of  67 | elapsed:    0.0s finished
# Features: 68/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 241 out of 241 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  68 out of  68 | elapsed:    0.0s finished
# Features: 69/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 240 out of 240 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  69 out of  69 | elapsed:    0.0s finished
# Features: 70/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 239 out of 239 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:    0.0s finished
# Features: 71/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 238 out of 238 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  71 out of  71 | elapsed:    0.0s finished
# Features: 72/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 237 out of 237 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  72 out of  72 | elapsed:    0.0s finished
# Features: 73/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 236 out of 236 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  73 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  73 out of  73 | elapsed:    0.0s finished
# Features: 74/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 235 out of 235 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  74 out of  74 | elapsed:    0.0s finished
# Features: 75/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 234 out of 234 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  52 out of  75 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  75 out of  75 | elapsed:    0.1s finished
# Features: 76/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 233 out of 233 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  76 out of  76 | elapsed:    0.1s finished
# Features: 77/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 232 out of 232 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  54 out of  77 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  77 out of  77 | elapsed:    0.0s finished
# Features: 78/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 231 out of 231 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  78 out of  78 | elapsed:    0.1s finished
# Features: 79/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 230 out of 230 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  56 out of  79 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  79 out of  79 | elapsed:    0.0s finished
# Features: 80/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 229 out of 229 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:    0.0s finished
# Features: 81/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 228 out of 228 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  58 out of  81 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed:    0.0s finished
# Features: 82/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 227 out of 227 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  82 out of  82 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  58 out of  81 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed:    0.0s finished
# Features: 82/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 227 out of 227 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  82 out of  82 | elapsed:    0.0s finished
# Features: 83/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 226 out of 226 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  60 out of  83 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  83 out of  83 | elapsed:    0.1s finished
# Features: 84/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 225 out of 225 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# Features: 85/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 224 out of 224 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  62 out of  85 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  85 out of  85 | elapsed:    0.1s finished
# Features: 86/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 223 out of 223 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  86 out of  86 | elapsed:    0.1s finished
# Features: 87/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 222 out of 222 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  64 out of  87 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  87 out of  87 | elapsed:    0.1s finished
# Features: 88/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 221 out of 221 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  88 out of  88 | elapsed:    0.1s finished
# Features: 89/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 220 out of 220 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  66 out of  89 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  89 out of  89 | elapsed:    0.1s finished
# Features: 90/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 219 out of 219 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:    0.1s finished
# Features: 91/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 218 out of 218 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  68 out of  91 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  91 out of  91 | elapsed:    0.1s finished
# Features: 92/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 217 out of 217 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  92 out of  92 | elapsed:    0.1s finished
# Features: 93/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 216 out of 216 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  93 out of  93 | elapsed:    0.1s finished
# Features: 94/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 215 out of 215 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  94 out of  94 | elapsed:    0.1s finished
# Features: 95/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 214 out of 214 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  95 out of  95 | elapsed:    0.1s finished
# Features: 96/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 213 out of 213 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed:    0.1s finished
# Features: 97/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 212 out of 212 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  97 out of  97 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed:    0.1s finished
# Features: 97/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 212 out of 212 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  97 out of  97 | elapsed:    0.1s finished
# Features: 98/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 211 out of 211 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  98 out of  98 | elapsed:    0.1s finished
# Features: 99/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 210 out of 210 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  99 out of  99 | elapsed:    0.1s finished
# Features: 100/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 209 out of 209 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.1s finished
# Features: 101/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 208 out of 208 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 101 out of 101 | elapsed:    0.1s finished
# Features: 102/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 207 out of 207 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 102 out of 102 | elapsed:    0.1s finished
# Features: 103/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 206 out of 206 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 103 out of 103 | elapsed:    0.1s finished
# Features: 104/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 205 out of 205 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 104 out of 104 | elapsed:    0.1s finished
# Features: 105/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 204 out of 204 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:    0.1s finished
# ...
# [Parallel(n_jobs=-1)]: Done 289 out of 289 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 288 out of 288 | elapsed:    0.8s finished
# Features: 289/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 289 out of 289 | elapsed:    0.8s finished
# Features: 290/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  19 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 290 out of 290 | elapsed:    0.8s finished
# Features: 291/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  18 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 291 out of 291 | elapsed:    0.8s finished
# Features: 292/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  17 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 292 out of 292 | elapsed:    0.8s finished
# Features: 293/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  16 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 293 out of 293 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 292 out of 292 | elapsed:    0.8s finished
# Features: 293/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  16 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 293 out of 293 | elapsed:    0.8s finished
# Features: 294/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 294 out of 294 | elapsed:    0.8s finished
# Features: 295/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  14 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 295 out of 295 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 294 out of 294 | elapsed:    0.9s finished
# Features: 295/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  14 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 295 out of 295 | elapsed:    0.8s finished
# Features: 296/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  13 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 296 out of 296 | elapsed:    0.9s finished
# Features: 297/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  12 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 297 out of 297 | elapsed:    0.9s finished
# Features: 298/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 298 out of 298 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 297 out of 297 | elapsed:    0.9s finished
# Features: 298/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 298 out of 298 | elapsed:    0.9s finished
# Features: 299/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 299 out of 299 | elapsed:    0.9s finished
# Features: 300/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   9 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:    0.9s finished
# Features: 301/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 301 out of 301 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:    0.9s finished
# Features: 301/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 301 out of 301 | elapsed:    0.9s finished
# Features: 302/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 302 out of 302 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 301 out of 301 | elapsed:    0.8s finished
# Features: 302/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 302 out of 302 | elapsed:    0.8s finished
# Features: 303/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   6 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 303 out of 303 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 302 out of 302 | elapsed:    0.9s finished
# Features: 303/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   6 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 303 out of 303 | elapsed:    0.9s finished
# Features: 304/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 304 out of 304 | elapsed:    0.9s finished
# Features: 305/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 305 out of 305 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 304 out of 304 | elapsed:    1.0s finished
# Features: 305/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 282 out of 305 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 305 out of 305 | elapsed:    0.9s finished
# Features: 306/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 306 out of 306 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 305 out of 305 | elapsed:    0.9s finished
# Features: 306/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 306 out of 306 | elapsed:    0.9s finished
# Features: 307/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 307 out of 307 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 283 out of 306 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 306 out of 306 | elapsed:    0.9s finished
# Features: 307/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 307 out of 307 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 306 out of 306 | elapsed:    0.9s finished
# Features: 307/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 307 out of 307 | elapsed:    1.0s finished
# Features: 308/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 308 out of 308 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 307 out of 307 | elapsed:    1.0s finished
# Features: 308/309[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 308 out of 308 | elapsed:    0.9s finished
# Features: 309/309
# SequentialFeatureSelector(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#                           estimator=SGDClassifier(alpha=0.01, loss='log'),
#                           floating=True, k_features='best', n_jobs=-1,
#                           scoring='f1', verbose=1)

# %%
# Now lets select the best features and check the performance
train_features_selected = selector.transform(train_features.tocsr())
test_features_selected = selector.transform(test_features.tocsr())

run_log_reg(train_features_selected, test_features_selected, y_train, y_test, alpha = 1e-2)
# Out:
# F1: 0.806 | Pr: 0.799 | Re: 0.892 | AUC: 0.903 | Accuracy: 0.842
# SGDClassifier(alpha=0.01, loss='log', n_jobs=-1)

# %%
log_reg.fit(train_features_selected, y_train)
y_pred_prob = (log_reg.predict_proba(test_features_selected)[:,1])


print_model_metrics(y_test, y_pred_prob, confusion = True)
# Out:
# F1: 0.846 | Pr: 0.857 | Re: 0.923 | AUC: 0.874 | Accuracy: 0.833

# %%
print('Num of features selected : {}'.format(len(selector.k_feature_idx_)))
np.array(feature_names)[list(selector.k_feature_idx_)]
# Out:
# Num of features selected : 53
# array(['train_emoji_re', 'length_in_chars', 'fasttext_3', 'fasttext_7',
#        'fasttext_8', 'fasttext_9', 'fasttext_10', 'fasttext_13',
#        'fasttext_17', 'fasttext_22', 'fasttext_24', 'fasttext_26',
#        'fasttext_31', 'fasttext_35', 'fasttext_37', 'fasttext_41',
#        'fasttext_44', 'fasttext_55', 'fasttext_56', 'fasttext_59',
#        'fasttext_65', 'fasttext_71', 'fasttext_72', 'fasttext_75',
#        'fasttext_86', 'fasttext_90', 'fasttext_94', 'fasttext_97',
#        'fasttext_99', 'fasttext_104', 'fasttext_111', 'fasttext_119',
#        'fasttext_127', 'fasttext_128', 'fasttext_134', 'fasttext_141',
#        'fasttext_146', 'fasttext_157', 'fasttext_167', 'fasttext_170',
#        'fasttext_171', 'fasttext_175', 'fasttext_185', 'fasttext_219',
#        'fasttext_220', 'fasttext_236', 'fasttext_240', 'fasttext_249',
#        'fasttext_251', 'fasttext_260', 'fasttext_276', 'fasttext_285',
#        'fasttext_287'], dtype='<U19')

# %% [markdown]
# ## Decomposition
# Unlike feature selection which picks the best features, decomposition techniques factorize the feature matrix to reduce the dimensionality. Since these techniques change the feature space itself, one disadvantage is that we lose model/feature interpretability. We no longer know what each dimension of the decomposed feature space represents.

# %% [markdown]
# ### TruncatedSVD

# %%
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(train_features.shape[1] - 1)
svd.fit(train_features)
# Out:
# TruncatedSVD(n_components=308)

# %%
# We want to find the number of components that explains most of the variance
plt.plot(np.cumsum(svd.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance')
plt.title('Number of Components vs Explained Variance')
# Out:
# Text(0.5, 1.0, 'Number of Components vs Explained Variance')

# %% [markdown]
# Looks like just 60 components is enough to explain 100% of the variance in the training set features. This means we have a lot of dependent features (i.e. some features are just linear combinations of other features).

# %%
# Lets go ahead and reduce dimensionality to 60

svd = TruncatedSVD(60)
train_featurse_decomposed = svd.fit_transform(train_features)
test_featurse_decomposed = svd.transform(test_features)

# %%
run_log_reg(train_featurse_decomposed, test_featurse_decomposed, y_train, y_test, alpha = 1e-1)
# Out:
# F1: 0.667 | Pr: 0.542 | Re: 1.000 | AUC: 0.476 | Accuracy: 0.500
# SGDClassifier(alpha=0.1, loss='log', n_jobs=-1)

# %% [markdown]
# The performance is not as good as the feature selection techniques. Why ?
#
# The main job of decomposition techniques, like TruncatedSVD, is to explain the variance in the dataset with fewer number of components. While doing this, it never considers the importance each feature had in predicting the target ('neurotic' or 'not-neurotic'). However, in the feature selection techniques, the feature importance or model weights is used each time a feature is removed or added. RFE and SFS in particular select features to optimize for model performance.

# %% [markdown]
# ## Stacking Classifier with Feature Selection

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model


batch_size = 128
epochs = 40

simple_nn = Sequential()
simple_nn.add(Dense(150, activation='relu', input_shape=(53,)))
simple_nn.add(Dropout(0.2))
simple_nn.add(Dense(100, activation='relu'))
simple_nn.add(Dropout(0.2))
simple_nn.add(Dense(1, activation='sigmoid'))

simple_nn.summary()

simple_nn.compile(loss='binary_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

checkpoint = ModelCheckpoint('Joel\\saved_models\\neuro_stacking_w_feature_selection', monitor = 'val_accuracy', verbose = 1, save_best_only=True)
history = simple_nn.fit(train_features_selected.todense(), y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks = [checkpoint],
                    validation_data=(test_features_selected.todense(), y_test))

simple_nn = load_model('Joel\\saved_models\\neuro_stacking_w_feature_selection')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 150)               8100
#
#  dropout_2 (Dropout)         (None, 150)               0
#
#  dense_4 (Dense)             (None, 100)               15100
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_5 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 23,301
# Trainable params: 23,301
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 1/1 [==============================] - ETA: 0s - loss: 0.7331 - accuracy: 0.3929
# Epoch 1: val_accuracy improved from -inf to 0.33333, saving model to Joel\saved_models\neuro_stacking_w_feature_selection
# INFO:tensorflow:Assets written to: Joel\saved_models\neuro_stacking_w_feature_selection\assets
# 1/1 [==============================] - 1s 1s/step - loss: 0.7331 - accuracy: 0.3929 - val_loss: 0.7072 - val_accuracy: 0.3333
# Epoch 2/40
# 1/1 [==============================] - ETA: 0s - loss: 0.7214 - accuracy: 0.4821
# Epoch 2: val_accuracy improved from 0.33333 to 0.54167, saving model to Joel\saved_models\neuro_stacking_w_feature_selection
# INFO:tensorflow:Assets written to: Joel\saved_models\neuro_stacking_w_feature_selection\assets
# 1/1 [==============================] - 1s 569ms/step - loss: 0.7214 - accuracy: 0.4821 - val_loss: 0.7002 - val_accuracy: 0.5417
# Epoch 3/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6855 - accuracy: 0.5357
# Epoch 3: val_accuracy did not improve from 0.54167
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6855 - accuracy: 0.5357 - val_loss: 0.7010 - val_accuracy: 0.5417
# Epoch 4/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6630 - accuracy: 0.6071
# Epoch 4: val_accuracy did not improve from 0.54167
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6630 - accuracy: 0.6071 - val_loss: 0.7052 - val_accuracy: 0.5417
# Epoch 5/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6646 - accuracy: 0.6250
# Epoch 5: val_accuracy did not improve from 0.54167
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6646 - accuracy: 0.6250 - val_loss: 0.7099 - val_accuracy: 0.5417
# Epoch 6/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6571 - accuracy: 0.6250
# Epoch 6: val_accuracy did not improve from 0.54167
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6571 - accuracy: 0.6250 - val_loss: 0.7118 - val_accuracy: 0.5417
# Epoch 7/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6646 - accuracy: 0.6250
# Epoch 7: val_accuracy did not improve from 0.54167
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6646 - accuracy: 0.6250 - val_loss: 0.7111 - val_accuracy: 0.5417
# Epoch 8/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6558 - accuracy: 0.6429
# Epoch 8: val_accuracy did not improve from 0.54167
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6558 - accuracy: 0.6429 - val_loss: 0.7070 - val_accuracy: 0.5417
# Epoch 9/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6705 - accuracy: 0.6250
# Epoch 9: val_accuracy did not improve from 0.54167
# 1/1 [==============================] - 0s 36ms/step - loss: 0.6705 - accuracy: 0.6250 - val_loss: 0.7014 - val_accuracy: 0.5417
# Epoch 10/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6490 - accuracy: 0.6250
# Epoch 10: val_accuracy did not improve from 0.54167
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6490 - accuracy: 0.6250 - val_loss: 0.6946 - val_accuracy: 0.5417
# Epoch 11/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6473 - accuracy: 0.6250
# Epoch 11: val_accuracy did not improve from 0.54167
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6473 - accuracy: 0.6250 - val_loss: 0.6867 - val_accuracy: 0.5417
# Epoch 12/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6258 - accuracy: 0.6250
# Epoch 12: val_accuracy did not improve from 0.54167
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6258 - accuracy: 0.6250 - val_loss: 0.6799 - val_accuracy: 0.5417
# Epoch 13/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6404 - accuracy: 0.6250
# Epoch 13: val_accuracy did not improve from 0.54167
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6404 - accuracy: 0.6250 - val_loss: 0.6739 - val_accuracy: 0.5417
# Epoch 14/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6216 - accuracy: 0.5893
# Epoch 14: val_accuracy did not improve from 0.54167
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6216 - accuracy: 0.5893 - val_loss: 0.6689 - val_accuracy: 0.5417
# Epoch 15/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6326 - accuracy: 0.6429
# Epoch 15: val_accuracy did not improve from 0.54167
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6326 - accuracy: 0.6429 - val_loss: 0.6646 - val_accuracy: 0.5417
# Epoch 16/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6581 - accuracy: 0.6071
# Epoch 16: val_accuracy improved from 0.54167 to 0.58333, saving model to Joel\saved_models\neuro_stacking_w_feature_selection
# INFO:tensorflow:Assets written to: Joel\saved_models\neuro_stacking_w_feature_selection\assets
# 1/1 [==============================] - 1s 533ms/step - loss: 0.6581 - accuracy: 0.6071 - val_loss: 0.6611 - val_accuracy: 0.5833
# Epoch 17/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6460 - accuracy: 0.6607
# Epoch 17: val_accuracy improved from 0.58333 to 0.62500, saving model to Joel\saved_models\neuro_stacking_w_feature_selection
# INFO:tensorflow:Assets written to: Joel\saved_models\neuro_stacking_w_feature_selection\assets
# 1/1 [==============================] - 1s 667ms/step - loss: 0.6460 - accuracy: 0.6607 - val_loss: 0.6578 - val_accuracy: 0.6250
# Epoch 18/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6266 - accuracy: 0.6964
# Epoch 18: val_accuracy did not improve from 0.62500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6266 - accuracy: 0.6964 - val_loss: 0.6542 - val_accuracy: 0.6250
# Epoch 19/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6168 - accuracy: 0.6607
# Epoch 19: val_accuracy did not improve from 0.62500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6168 - accuracy: 0.6607 - val_loss: 0.6509 - val_accuracy: 0.6250
# Epoch 20/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6349 - accuracy: 0.5893
# Epoch 20: val_accuracy did not improve from 0.62500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6349 - accuracy: 0.5893 - val_loss: 0.6472 - val_accuracy: 0.6250
# Epoch 21/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6177 - accuracy: 0.6964
# Epoch 21: val_accuracy did not improve from 0.62500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6177 - accuracy: 0.6964 - val_loss: 0.6435 - val_accuracy: 0.5833
# Epoch 22/40
# 1/1 [==============================] - ETA: 0s - loss: 0.5924 - accuracy: 0.6429
# Epoch 22: val_accuracy did not improve from 0.62500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5924 - accuracy: 0.6429 - val_loss: 0.6397 - val_accuracy: 0.5833
# Epoch 23/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6045 - accuracy: 0.6607
# Epoch 23: val_accuracy did not improve from 0.62500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6045 - accuracy: 0.6607 - val_loss: 0.6364 - val_accuracy: 0.5833
# Epoch 24/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6163 - accuracy: 0.6607
# Epoch 24: val_accuracy did not improve from 0.62500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6163 - accuracy: 0.6607 - val_loss: 0.6336 - val_accuracy: 0.5833
# Epoch 25/40
# 1/1 [==============================] - ETA: 0s - loss: 0.5921 - accuracy: 0.6429
# Epoch 25: val_accuracy did not improve from 0.62500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5921 - accuracy: 0.6429 - val_loss: 0.6305 - val_accuracy: 0.5833
# Epoch 26/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6237 - accuracy: 0.5893
# Epoch 26: val_accuracy did not improve from 0.62500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6237 - accuracy: 0.5893 - val_loss: 0.6269 - val_accuracy: 0.5833
# Epoch 27/40
# 1/1 [==============================] - ETA: 0s - loss: 0.5785 - accuracy: 0.6607
# Epoch 27: val_accuracy did not improve from 0.62500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.5785 - accuracy: 0.6607 - val_loss: 0.6232 - val_accuracy: 0.6250
# Epoch 28/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6009 - accuracy: 0.6429
# Epoch 28: val_accuracy improved from 0.62500 to 0.66667, saving model to Joel\saved_models\neuro_stacking_w_feature_selection
# INFO:tensorflow:Assets written to: Joel\saved_models\neuro_stacking_w_feature_selection\assets
# 1/1 [==============================] - 1s 575ms/step - loss: 0.6009 - accuracy: 0.6429 - val_loss: 0.6202 - val_accuracy: 0.6667
# Epoch 29/40
# 1/1 [==============================] - ETA: 0s - loss: 0.6067 - accuracy: 0.5714
# Epoch 29: val_accuracy improved from 0.66667 to 0.75000, saving model to Joel\saved_models\neuro_stacking_w_feature_selection
# INFO:tensorflow:Assets written to: Joel\saved_models\neuro_stacking_w_feature_selection\assets
# 1/1 [==============================] - 1s 547ms/step - loss: 0.6067 - accuracy: 0.5714 - val_loss: 0.6171 - val_accuracy: 0.7500
# Epoch 30/40
# 1/1 [==============================] - ETA: 0s - loss: 0.5783 - accuracy: 0.5893
# Epoch 30: val_accuracy did not improve from 0.75000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5783 - accuracy: 0.5893 - val_loss: 0.6145 - val_accuracy: 0.7500
# Epoch 31/40
# 1/1 [==============================] - ETA: 0s - loss: 0.5628 - accuracy: 0.7679
# Epoch 31: val_accuracy did not improve from 0.75000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5628 - accuracy: 0.7679 - val_loss: 0.6121 - val_accuracy: 0.7500
# Epoch 32/40
# 1/1 [==============================] - ETA: 0s - loss: 0.5841 - accuracy: 0.7321
# Epoch 32: val_accuracy did not improve from 0.75000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5841 - accuracy: 0.7321 - val_loss: 0.6098 - val_accuracy: 0.7500
# Epoch 33/40
# 1/1 [==============================] - ETA: 0s - loss: 0.5586 - accuracy: 0.7143
# Epoch 33: val_accuracy did not improve from 0.75000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5586 - accuracy: 0.7143 - val_loss: 0.6068 - val_accuracy: 0.7500
# Epoch 34/40
# 1/1 [==============================] - ETA: 0s - loss: 0.5514 - accuracy: 0.6964
# Epoch 34: val_accuracy did not improve from 0.75000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5514 - accuracy: 0.6964 - val_loss: 0.6037 - val_accuracy: 0.7500
# Epoch 35/40
# 1/1 [==============================] - ETA: 0s - loss: 0.5814 - accuracy: 0.6607
# Epoch 35: val_accuracy did not improve from 0.75000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5814 - accuracy: 0.6607 - val_loss: 0.6004 - val_accuracy: 0.7500
# Epoch 36/40
# 1/1 [==============================] - ETA: 0s - loss: 0.5558 - accuracy: 0.7143
# Epoch 36: val_accuracy did not improve from 0.75000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5558 - accuracy: 0.7143 - val_loss: 0.5977 - val_accuracy: 0.7500
# Epoch 37/40
# 1/1 [==============================] - ETA: 0s - loss: 0.5509 - accuracy: 0.7500
# Epoch 37: val_accuracy did not improve from 0.75000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5509 - accuracy: 0.7500 - val_loss: 0.5951 - val_accuracy: 0.7500
# Epoch 38/40
# 1/1 [==============================] - ETA: 0s - loss: 0.5656 - accuracy: 0.6607
# Epoch 38: val_accuracy did not improve from 0.75000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5656 - accuracy: 0.6607 - val_loss: 0.5925 - val_accuracy: 0.7500
# Epoch 39/40
# 1/1 [==============================] - ETA: 0s - loss: 0.5436 - accuracy: 0.7321
# Epoch 39: val_accuracy did not improve from 0.75000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5436 - accuracy: 0.7321 - val_loss: 0.5897 - val_accuracy: 0.7500
# Epoch 40/40
# 1/1 [==============================] - ETA: 0s - loss: 0.5211 - accuracy: 0.7500
# Epoch 40: val_accuracy did not improve from 0.75000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5211 - accuracy: 0.7500 - val_loss: 0.5870 - val_accuracy: 0.7500

# %%
y_pred_prob = simple_nn.predict(test_features_selected.todense())
print_model_metrics(y_test, y_pred_prob)
# Out:
# 1/1 [==============================] - 0s 75ms/step
# F1: 0.800 | Pr: 0.722 | Re: 1.000 | AUC: 0.881 | Accuracy: 0.750

# %%
def run_voting_clf(model_weights):
    #result_list, model_weights = data
    
    y_pred_prob = 0

    for model_name, model in model_dict.items():
        y_pred_prob += (model.predict_proba(test_features_selected)[:,1] * model_weights[model_name])

    #y_pred_prob += (simple_nn.get_preds(ds_type = DatasetType.Valid)[0].numpy()[:,0] * model_weights['simple_nn'])
    y_pred_prob += (simple_nn.predict(test_features_selected.todense()).ravel() * model_weights['simple_nn'])
    y_pred_prob /= sum(model_weights.values())
    f1 = print_model_metrics(y_test, y_pred_prob, return_metrics = True, verbose = 0)[0]
    return {'loss' : -f1, 'status' : STATUS_OK}

# %%
# Define all models 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier

lr = SGDClassifier(loss = 'log', alpha = 0.01, penalty = 'l2', l1_ratio = 0.25) # LR Best Parameters : {'alpha': 0.01, 'l1_ratio': 0.25, 'penalty': 'l2'}
svm = SVC(C = 0.1, kernel = 'linear', degree=2, probability = True) # SVM Best Parameters : {'C': 0.1, 'degree': 2, 'kernel': 'linear'}
nb = MultinomialNB(alpha = 100, class_prior = [0.5, 0.5]) # NB Best Parameters : {'alpha': 100}
knn = KNeighborsClassifier(n_neighbors = 9, weights = 'uniform', n_jobs = -1) # KNN Best Parameters : {'n_neighbors': 9, 'weights': 'uniform'}
rf = RandomForestClassifier(n_estimators = 100, min_samples_split = 5, max_depth = None,  n_jobs = -1) # RF Best Parameters : {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 100}
xgb = XGBClassifier(n_estimators = 10, learning_rate = 0.3, reg_alpha= 0, max_depth = 1, n_jobs = -1) # XGB Best Parameters : {'learning_rate': 0.3, 'max_depth': 1, 'n_estimators': 10, 'reg_alpha': 0}


model_dict = dict(zip(['LR', 'SVM', 'NB', 'KNN', 'RF', 'XGB'], [lr, svm, nb, knn, rf, xgb]))

for model_name, model in model_dict.items():
    print('Training {}'.format(model_name))
    model.fit(train_features_selected, y_train)

model_weights = {'KNN': 0.12297099497078773,
 'LR': 0.8528779963033659,
 'NB': 0.703824127065576,
 'RF': 0.13006445567555272,
 'SVM': 0.6685697689597849,
 'XGB': 0.03163436945758728,
 'simple_nn': 0.37772797931020696}

y_pred_prob = 0

for model_name, model in model_dict.items():
    y_pred_prob += (model.predict_proba(test_features_selected)[:,1] * model_weights[model_name])

y_pred_prob += (simple_nn.predict(test_features_selected.todense()).ravel() * model_weights['simple_nn'])
y_pred_prob /= sum(model_weights.values())

print_model_metrics(y_test, y_pred_prob)
# Out:
# Training LR
# Training SVM
# Training NB
# Training KNN
# Training RF
# Training XGB
# 1/1 [==============================] - 0s 20ms/step
# F1: 0.889 | Pr: 0.867 | Re: 1.000 | AUC: 0.909 | Accuracy: 0.875

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

trials = Trials()
model_weights = fmin(run_voting_clf,
    space= {
        'LR' : hp.uniform('LR', 0, 1),
        'SVM' : hp.uniform('SVM', 0, 1),
        'NB' : hp.uniform('NB', 0, 1),
        'KNN' : hp.uniform('KNN', 0, 1),
        'RF' : hp.uniform('RF', 0, 1),
        'XGB' : hp.uniform('XGB', 0, 1),
        'simple_nn' : hp.uniform('simple_nn', 0, 1),


    },
    algo=tpe.suggest,
    max_evals=100,
    trials = trials)
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 23ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 25ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 23ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 22ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 22ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 22ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 22ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 19ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 22ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 22ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 23ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 22ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 22ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 24ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 22ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 21ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 23ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 24ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 20ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 23ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 23ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 24ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 23ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 24ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 22ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 23ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 23ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 22ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 24ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 22ms/step
#
# 100%|█████████████████████████████████████████████| 100/100 [00:10<00:00,  9.50trial/s, best loss: -0.8571428571428571]

# %%
model_weights
# Out:
# {'KNN': 0.12297099497078773,
#  'LR': 0.8528779963033659,
#  'NB': 0.703824127065576,
#  'RF': 0.13006445567555272,
#  'SVM': 0.6685697689597849,
#  'XGB': 0.03163436945758728,
#  'simple_nn': 0.37772797931020696}

# %%
y_pred_prob = 0

for model_name, model in model_dict.items():
    y_pred_prob += (model.predict_proba(test_features_selected)[:,1] * model_weights[model_name])

y_pred_prob += (simple_nn.predict(test_features_selected.todense()).ravel() * model_weights['simple_nn'])
y_pred_prob /= sum(model_weights.values())

print_model_metrics(y_test, y_pred_prob, confusion = True)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# F1: 0.889 | Pr: 0.867 | Re: 1.000 | AUC: 0.909 | Accuracy: 0.875

# %%
precision, recall, threshold = precision_recall_curve(y_test, y_pred_prob, pos_label = 1)
    
#Find the threshold value that gives the best F1 Score
best_f1_index =np.argmax([calc_f1(p_r) for p_r in zip(precision, recall)])
best_threshold, best_precision, best_recall = threshold[best_f1_index], precision[best_f1_index], recall[best_f1_index]

# Calulcate predictions based on the threshold value
y_test_pred = np.where(y_pred_prob > best_threshold, 1, 0)
misclassified_idx = y_test == y_test_pred
high_confidence_indices = np.argsort(y_pred_prob[misclassified_idx])[-10:]

for idx in high_confidence_indices:
    print('Title : {}'.format(test[misclassified_idx].text.values[idx]))
    print('Label : {}'.format(test[misclassified_idx].neuro_bin.values[idx]))
    print('Predicted Probability : {}'.format(y_pred_prob[misclassified_idx][idx]))
    print('-' * 10)

# %%
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.metrics import make_scorer
from scipy import sparse


def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn


def adjusted_f1(y_true, y_prob):
    f1 = print_model_metrics(y_true, y_prob, verbose = 0, return_metrics = True)[0]
    return f1

score = make_scorer(adjusted_f1, greater_is_better = True, needs_proba = True)



# Since we want to use a predefined Test/Val set, we'll use PredefinedSplit and pass it as the CV parameter
# We need to merge both the datasets and label 0 for test and -1 for the train set

X = sparse.vstack((train_features_selected, test_features_selected))
test_fold = [-1 for _ in range(train_features_selected.shape[0])] + [0 for _ in range(test_features_selected.shape[0])]
y = np.concatenate([y_train, y_test])
ps = PredefinedSplit(test_fold)

def run_grid_search(model, params, x_train, y_train):
    grid = GridSearchCV(model, params, cv = ps, n_jobs = -1, scoring = score, verbose = 0, refit = False)
    grid.fit(x_train, y_train)
    return (grid.best_params_, grid.best_score_)

# Run log reg n times and average the metrics
def fit_n_times(model, x_train, y_train, x_test, y_test, n_iters = 10):
    metrics = np.zeros(5)
    for _ in range(n_iters):
        model.fit(x_train, y_train)
        y_test_prob = model.predict_proba(x_test)[:,1]
        metrics += print_model_metrics(y_test, y_test_prob, verbose = False, return_metrics = True)
    metrics /=10
    print('F1: {:.3f} | Pr: {:.3f} | Re: {:.3f} | AUC: {:.3f} | Accuracy: {:.3f} \n'.format(*metrics))
    

from sklearn.linear_model import SGDClassifier

lr = SGDClassifier(loss = 'log')
lr_params = {'alpha' : [10**(-x) for x in range(7)],
             'penalty' : ['l1', 'l2', 'elasticnet'],
             'l1_ratio' : [0.15, 0.25, 0.5, 0.75]}

best_params, best_f1 = run_grid_search(lr, lr_params, X, y)

print('LR Best Parameters : {}'.format(best_params))
print('Best F1 : {}'.format(best_f1))


from sklearn.svm import SVC

svm = SVC(probability = True)
svm_params = {'C' : [10**(x) for x in range(-1,4)],
             'kernel' : ['poly', 'rbf', 'linear'],
             'degree' : [2, 3]}

best_params, best_f1 = run_grid_search(svm, svm_params, X, y)

print('SVM Best Parameters : {}'.format(best_params))
print('Best F1 : {}'.format(best_f1))

from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB(class_prior = [0.5, 0.5])
nb_params = {'alpha' : [10**(x) for x in range(6)]}


best_params, best_f1 = run_grid_search(nb, nb_params, X, y)

print('NB Best Parameters : {}'.format(best_params))
print('Best F1 : {}'.format(best_f1))

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_jobs = -1)

knn_params = { 'n_neighbors' : [3, 5, 7, 9, 15, 31], 
               'weights' : ['uniform', 'distance']
}

best_params, best_f1 = run_grid_search(knn, knn_params, X, y)
print('KNN Best Parameters : {}'.format(best_params))
print('Best F1 : {}'.format(best_f1))

from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_jobs = -1)

rf_params = { 'n_estimators' : [10, 100, 250, 500, 1000], 
               'max_depth' : [None, 3, 7, 15],
               'min_samples_split' : [2, 5, 15]
}

best_params, best_f1 = run_grid_search(rf, rf_params, X, y)

print('RF Best Parameters : {}'.format(best_params))
print('Best F1 : {}'.format(best_f1))

from xgboost import XGBClassifier

xgb = XGBClassifier(n_jobs = 1)

xgb_params = { 'n_estimators' : [10, 100, 200, 500], 
               'max_depth' : [1, 2, 3, 7],
               'learning_rate' : [0.1, 0.2, 0.01, 0.3],
               'reg_alpha' : [0, 0.1, 0.2]
}

best_params, best_f1 = run_grid_search(xgb, xgb_params, X, y)

print('XGB Best Parameters : {}'.format(best_params))
print('Best F1 : {}'.format(best_f1))
# Out:
# LR Best Parameters : {'alpha': 0.01, 'l1_ratio': 0.25, 'penalty': 'l2'}
# Best F1 : 0.888888888888889
# SVM Best Parameters : {'C': 0.1, 'degree': 2, 'kernel': 'linear'}
# Best F1 : 0.7692307692307693
# NB Best Parameters : {'alpha': 100}
# Best F1 : 0.7692307692307693
# KNN Best Parameters : {'n_neighbors': 9, 'weights': 'uniform'}
# Best F1 : 0.7333333333333334
# RF Best Parameters : {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 100}
# Best F1 : 0.8571428571428571
# XGB Best Parameters : {'learning_rate': 0.3, 'max_depth': 1, 'n_estimators': 10, 'reg_alpha': 0}
# Best F1 : 0.8275862068965517
